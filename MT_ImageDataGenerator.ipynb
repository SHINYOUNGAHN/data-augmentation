# %% [markdown]
# # 4개국 화폐 이미지 데이터 증식
# ---
# - 4개국: 중국, 일본, 한국, 미국
# - 각 폴더별 30개의 이미지파일 * 4 = 120장이상 혹은 이하로 증식

# %% [markdown]
# ## 1. 중국 화폐 (CNY_yuan) 데이터
# ---
# - 폴더: 9개, 중국 화폐단위: 9개
# - 폴더명 == 중국 화폐 단위
# - directory = ['1jiao','1yuan','1yuan_coin','5jiao','5yuan', '10yuan', '20yuan', '50yuan', '100yuan']

# %%
import numpy as np
import string
import glob
from pathlib import Path
import os

from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

# 랜덤시드 고정시키기
np.random.seed(5)

# 데이터셋 불러오기
data_aug_gen = ImageDataGenerator(rescale=None, 
                                  rotation_range=15,
                                  width_shift_range=0.1,
                                  height_shift_range=0.1,
                                  shear_range=0.5,
                                  zoom_range=[0.8, 2.0],
                                  horizontal_flip=True,
                                  #vertical_flip=True,
                                  fill_mode='nearest')

directory = ['1jiao','1yuan','1yuan_coin','5jiao','5yuan', '10yuan', '20yuan', '50yuan', '100yuan']

# 디렉토리별로 돌아가면서 모든 사진들에 대해서 +4장씩 데이터를 증식시킴(클래스별 총 데이터 수가 30*4=120장이상이 됨)
for _ in directory:
    path = r'C:\\Users\\user\\Downloads\\ML-master\\ML-master\\dataset\\cny\\'+_
    file_list = glob.glob(path+'\\*.JPG')
    print(_+"\n")
    
    
    for eachImgPath in file_list:
        img = load_img(eachImgPath)
        x = img_to_array(img)
        x = x.reshape((1,) + x.shape)

        i = 0

        # 이 for는 무한으로 반복되기 때문에 우리가 원하는 반복횟수를 지정하여, 지정된 반복횟수가 되면 빠져나오도록 해야합니다.
        for batch in data_aug_gen.flow(
                                    x, batch_size=1, 
                                    save_to_dir=path, 
                                    save_prefix=_, 
                                    save_format='jpg'):
            i += 1
            if i > 3: 
                break
# Out:
# 1jiao
#
# 1yuan
#
# 1yuan_coin
#
# 5jiao
#
# 5yuan
#
# 10yuan
#
# 20yuan
#
# 50yuan
#
# 100yuan

# %% [markdown]
# ## 2. 일본 화폐(JPY_yen) 데이터
# ---
# - 폴더: 9개, 일본 화폐단위: 9가지
# - 폴더명 == 일본 화폐 단위
# - directory = ['1yen','5yen','10yen','50yen','100yen', '500yen', '1000yen', '5000yen', '10000yen']

# %%
import numpy as np
import string
import glob
from pathlib import Path
import os

from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

# 랜덤시드 고정시키기
np.random.seed(5)

# 데이터셋 불러오기
data_aug_gen = ImageDataGenerator(rescale=None, 
                                  rotation_range=15,
                                  width_shift_range=0.1,
                                  height_shift_range=0.1,
                                  shear_range=0.5,
                                  zoom_range=[0.8, 2.0],
                                  horizontal_flip=True,
                                  #vertical_flip=True,
                                  fill_mode='nearest')

directory = ['1yen','5yen','10yen','50yen','100yen', '500yen', '1000yen', '5000yen', '10000yen']

# 디렉토리별로 돌아가면서 모든 사진들에 대해서 +4장씩 데이터를 증식시킴(클래스별 총 데이터 수가 30*4=120장이상이 됨)
for _ in directory:
    path = r'C:\\Users\\user\\Downloads\\ML-master\\ML-master\\dataset\\jpy\\'+_
    file_list = glob.glob(path+'\\*.JPG')
    print(_+"\n")
    
    
    for eachImgPath in file_list:
        img = load_img(eachImgPath)
        x = img_to_array(img)
        x = x.reshape((1,) + x.shape)

        i = 0

        # 이 for는 무한으로 반복되기 때문에 우리가 원하는 반복횟수를 지정하여, 지정된 반복횟수가 되면 빠져나오도록 해야합니다.
        for batch in data_aug_gen.flow(
                                    x, batch_size=1, 
                                    save_to_dir=path, 
                                    save_prefix=_, 
                                    save_format='jpg'):
            i += 1
            if i > 3: 
                break
# Out:
# 1yen
#
# 5yen
#
# 10yen
#
# 50yen
#
# 100yen
#
# 500yen
#
# 1000yen
#
# 5000yen
#
# 10000yen

# %% [markdown]
# ## 3. 한국 화폐(KRW_won) 데이터
# ---
# - 폴더: 8개, 한국 화폐단위: 8가지
# - 폴더명 == 한국 화폐 단위
# - directory = ['10won','50won','100won','500won','1000won', '5000won', '10000won', '50000won']

# %%
import numpy as np
import string
import glob
from pathlib import Path
import os

from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

# 랜덤시드 고정시키기
np.random.seed(5)

# 데이터셋 불러오기
data_aug_gen = ImageDataGenerator(rescale=None, 
                                  rotation_range=15,
                                  width_shift_range=0.1,
                                  height_shift_range=0.1,
                                  shear_range=0.5,
                                  zoom_range=[0.8, 2.0],
                                  horizontal_flip=True,
                                  #vertical_flip=True,
                                  fill_mode='nearest')

directory = ['10won','50won','100won','500won','1000won', '5000won', '10000won', '50000won']

# 디렉토리별로 돌아가면서 모든 사진들에 대해서 +4장씩 데이터를 증식시킴(클래스별 총 데이터 수가 30*4=120장이상이 됨)
for _ in directory:
    path = r'C:\\Users\\user\\Downloads\\ML-master\\ML-master\\dataset\\krw\\'+_
    file_list = glob.glob(path+'\\*.JPG')
    print(_+"\n")
    
    
    for eachImgPath in file_list:
        img = load_img(eachImgPath)
        x = img_to_array(img)
        x = x.reshape((1,) + x.shape)

        i = 0

        # 이 for는 무한으로 반복되기 때문에 우리가 원하는 반복횟수를 지정하여, 지정된 반복횟수가 되면 빠져나오도록 해야합니다.
        for batch in data_aug_gen.flow(
                                    x, batch_size=1, 
                                    save_to_dir=path, 
                                    save_prefix=_, 
                                    save_format='jpg'):
            i += 1
            if i > 3: 
                break
# Out:
# 10won
#
# 50won
#
# 100won
#
# 500won
#
# 1000won
#
# 5000won
#
# 10000won
#
# 50000won

# %% [markdown]
# ## 4. 미국 화폐(USD_dollar) 데이터
# ---
# - 폴더: 10개, 미국 화폐단위: 10가지
# - 폴더명 == 미국 화폐 단위
# - directory = ['1cent', '1dollar', '5cent', '5dollar', '10cent', '10dollar', '20dollar', '25cent', '50dollar', '100dollar']

# %%
import numpy as np
import string
import glob
from pathlib import Path
import os

from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

# 랜덤시드 고정시키기
np.random.seed(5)

# 데이터셋 불러오기
data_aug_gen = ImageDataGenerator(rescale=None, 
                                  rotation_range=15,
                                  width_shift_range=0.1,
                                  height_shift_range=0.1,
                                  shear_range=0.5,
                                  zoom_range=[0.8, 2.0],
                                  horizontal_flip=True,
                                  #vertical_flip=True,
                                  fill_mode='nearest')

directory = ['1cent', '1dollar', '5cent', '5dollar', '10cent', '10dollar', '20dollar', '25cent', '50dollar', '100dollar']

# 디렉토리별로 돌아가면서 모든 사진들에 대해서 +4장씩 데이터를 증식시킴(클래스별 총 데이터 수가 30*4=120장이상이 됨)
for _ in directory:
    path = r'C:\\Users\\user\\Downloads\\ML-master\\ML-master\\dataset\\usd\\'+_
    file_list = glob.glob(path+'\\*.png')
    print(_+"\n")
    
    
    for eachImgPath in file_list:
        img = load_img(eachImgPath)
        x = img_to_array(img)
        x = x.reshape((1,) + x.shape)

        i = 0

        # 이 for는 무한으로 반복되기 때문에 우리가 원하는 반복횟수를 지정하여, 지정된 반복횟수가 되면 빠져나오도록 해야합니다.
        for batch in data_aug_gen.flow(
                                    x, batch_size=1, 
                                    save_to_dir=path, 
                                    save_prefix=_, 
                                    save_format='jpg'):
            i += 1
            if i > 3: 
                break
# Out:
# 1cent
#
# 1dollar
#
# 5cent
#
# 5dollar
#
# 10cent
#
# 10dollar
#
# 20dollar
#
# 25cent
#
# 50dollar
#
# 100dollar
